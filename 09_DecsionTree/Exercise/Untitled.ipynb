# %%
import pandas as pd

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
inputs=df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked','Survived'],axis='columns')
inputs
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
targets=df['Survived']
targets
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import tree
from sklearn.preprocessing import LabelEncoder

# %%
le_class=LabelEncoder() #4 ota coluns xa tesialey 4 ota object LabelEncoder() ley  convert a specific column into numbers.
le_sex=LabelEncoder()
le_age=LabelEncoder()
le_fare=LabelEncoder()

# %%
print(inputs['Age'].isnull().sum())
#If it's greater than 0, that means you have missing data.
# Out:
# 177

# %%
# inputs['encoded_class']=le_class.fit_transform(inputs['Pclass']) # yo garnu parney becauase PClass is already in number
inputs['encoded_sex']=le_sex.fit_transform(inputs['Sex'])
# inputs['encoded_age']=le_age.fit_transform(inputs['Age'])
inputs['encoded_age'] = inputs['Age'].astype(int) 

inputs['encoded_fare']=le_fare.fit_transform(inputs['Fare'])
inputs
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[33], line 4
#       2 inputs['encoded_sex']=le_sex.fit_transform(inputs['Sex'])
#       3 # inputs['encoded_age']=le_age.fit_transform(inputs['Age'])
# ----> 4 inputs['encoded_age'] = inputs['Age'].astype(int)
#       6 inputs['encoded_fare']=le_fare.fit_transform(inputs['Fare'])
#       7 inputs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
inputs_n=inputs.drop(['Pclass','Sex','Age','Fare'],axis='columns')
inputs_n
# Out:
#      encoded_class  encoded_sex  encoded_age
# 0               18            1           28
# 1              207            0           51
# 2               41            0           34
# 3              189            0           47
# 4               43            1           47
# ..             ...          ...          ...
# 886             85            1           35
# 887            153            0           24
# 888            131            0           88
# 889            153            1           34
# 890             30            1           42
#
# [891 rows x 3 columns]

# %%
model=tree.DecisionTreeClassifier()
model.fit(inputs_n,targets)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,targets)
# Out:
# 0.9797979797979798

# %%
model.predict([[18,1,28]])
# Out:
# C:\Users\atulm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
