# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Basic Graph

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y, label='2x', color='red')
plt.show()

# %%
plt.title('First title')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')
